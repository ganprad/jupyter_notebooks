# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('plants.csv',delimiter=',')
df.head(10)
# Out:
#   Symbol Synonym Symbol                        Scientific Name with Author  \
# 0  ABELI            NaN                                      Abelia R. Br.
# 1  ABGR4            NaN  Abelia ×grandiflora (Rovelli ex André) Rehder ...
# 2  ABELM            NaN                                 Abelmoschus Medik.
# 3   ABES            NaN                 Abelmoschus esculentus (L.) Moench
# 4   ABES           HIES                             Hibiscus esculentus L.
# 5  ABMA9            NaN         Abelmoschus manihot (L.) Medik. [excluded]
# 6  ABMA9          HIMA9                                Hibiscus manihot L.
# 7   ABMO            NaN                       Abelmoschus moschatus Medik.
# 8   ABMO           HIAB                            Hibiscus abelmoschus L.
# 9  ABIES            NaN                                        Abies Mill.
#
#      Common Name          Family
# 0         abelia  Caprifoliaceae
# 1  glossy abelia  Caprifoliaceae
# 2           okra       Malvaceae
# ...

# %%
df
# Out:
#        Symbol Synonym Symbol  \
# 0       ABELI            NaN
# 1       ABGR4            NaN
# 2       ABELM            NaN
# 3        ABES            NaN
# 4        ABES           HIES
# 5       ABMA9            NaN
# 6       ABMA9          HIMA9
# 7        ABMO            NaN
# 8        ABMO           HIAB
# 9       ABIES            NaN
# 10      ABAL3            NaN
# 11       ABAM            NaN
# 12      ABBAB            NaN
# 13      ABBAB          PIBA3
# 14      ABBAP            NaN
# 15      ABBAP           ABPH
# 16       ABBA            NaN
# 17       ABBR            NaN
# 18       ABBR           ABVE
# 19      ABCOC            NaN
# 20      ABCOL            NaN
# 21      ABCOL           ABLO
# 22       ABCO            NaN
# 23       ABFR            NaN
# 24       ABFR           PIFR
# 25       ABGR            NaN
# 26       ABGR          ABGRG
# 27       ABGR          ABGRI
# 28       ABGU            NaN
# 29       ABHO            NaN
# ...       ...            ...
# ...

# %%
df['Scientific Name with Author'] = df['Scientific Name with Author'].str.replace("[excluded]","")
#df['Scientific Name with Author'] = df['Scientific Name with Author'].str.replace(" []","")
df['Scientific Name with Author'] = df['Scientific Name with Author'].str.rstrip("L.")

# %%
df.sample(20)
# Out:
#        Symbol Synonym Symbol  \
# 343     ACNI2          MINI2
# 44608    KACA          KABR2
# 12274    BUVE          FIVE3
# 75384   SARU3            NaN
# 70936    RABU          RABUV
# 75375   SAROD          SADO8
# 46709   LETH6            NaN
# 83697   TETE7         LEAR21
# 53961   MIPE9          MITR8
# 56422  NETEP2            NaN
# 27095   DISAT          PACOO
# 23439   CRUDI            NaN
# 43875  JACQU3            NaN
# 32880    ERSH         ERSHL2
# 51488   MABL2            NaN
# 49580   LOBE2            NaN
# 59681   PADIP          PADII
# 16180  CADI20            NaN
# 43024   IPTEL          IPLE3
# 19648   CIAUB            NaN
#
#                              Scientific Name with Author  \
# 343                                       Mimosa niotia
# 44608                           Kastromia brahystyis Vai
# 12274                      Fimbristyis vstita (Knth) Hms
# 75384         Sai ×rbns Shrank (pro sp.) [aba × fragiis]
# ...
